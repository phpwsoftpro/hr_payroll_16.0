# %%
import os
import subprocess
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# Docker container name and paths
docker_container_name = "odoo16"
container_path = "/mnt/extra-addons/employee_payroll_attendance"
local_path = "D:/Wsoftpro/HR-Payroll/employee_payroll_attendance"
# Ensure the local folder exists
if not os.path.exists(local_path):
    os.makedirs(local_path)

# Function to check and create directory in Docker container if it doesn't exist
def create_directory_in_container(directory_in_container):
    # Check if directory exists in the container
    check_command = [
        "docker", "exec", docker_container_name, "bash", "-c", f"test -d {directory_in_container} || echo 'missing'"
    ]
    result = subprocess.run(check_command, capture_output=True, text=True)

    if 'missing' in result.stdout:
        print(f"Directory {directory_in_container} is missing in the container, creating it...")
        # Create the directory if it's missing
        create_command = [
            "docker", "exec", docker_container_name, "bash", "-c", f"mkdir -p {directory_in_container}"
        ]
        create_result = subprocess.run(create_command, capture_output=True, text=True)
        if create_result.returncode == 0:
            print(f"Successfully created directory: {directory_in_container}")
        else:
            print(f"Failed to create directory. Error: {create_result.stderr}")
    else:
        print(f"Directory {directory_in_container} exists in the container.")

# Function to sync a single file to the Docker container
def sync_file_to_container(src_path, relative_path):
    # Chuyển đổi đường dẫn Windows thành dạng Unix để tương thích với Docker
    dest_path = os.path.join(container_path, relative_path).replace("\\", "/")
    dest_dir = os.path.dirname(dest_path)  # Extract the directory part of the destination path

    # Ensure the target directory exists in the Docker container
    create_directory_in_container(dest_dir)

    print(f"Syncing {src_path} to {docker_container_name}:{dest_path}...")
    
    # Sử dụng docker cp để đồng bộ tệp đã thay đổi
    sync_command = [
        "docker", "cp", src_path, f"{docker_container_name}:{dest_path}"
    ]
    result = subprocess.run(sync_command, capture_output=True, text=True)
    
    if result.returncode == 0:
        print(f"Successfully synced {src_path} to Docker container.")
    else:
        print(f"Failed to sync {src_path}. Error: {result.stderr}")

# Function to download all files from Docker container to local folder (first run)
def download_from_container():
    print(f"Downloading all files from {docker_container_name}:{container_path} to {local_path}...")
    download_command = [
        "docker", "cp", f"{docker_container_name}:{container_path}.", local_path
    ]
    result = subprocess.run(download_command, capture_output=True, text=True)
    if result.returncode == 0:
        print(f"Successfully downloaded files to {local_path}.")
    else:
        print(f"Failed to download files from container. Error: {result.stderr}")

# File change handler for monitoring the local folder
class LocalFileChangeHandler(FileSystemEventHandler):
    def on_modified(self, event):
        # Ignore directory modifications and temporary files
        if event.is_directory or event.src_path.endswith('~'):
            return
        
        # Calculate the relative path of the changed file
        relative_path = os.path.relpath(event.src_path, local_path)
        sync_file_to_container(event.src_path, relative_path)

    def on_created(self, event):
        # Sync new files to the Docker container
        if not event.is_directory:
            relative_path = os.path.relpath(event.src_path, local_path)
            sync_file_to_container(event.src_path, relative_path)

# Function to start monitoring the local folder for changes
def start_monitoring():
    event_handler = LocalFileChangeHandler()
    observer = Observer()
    observer.schedule(event_handler, path=local_path, recursive=True)
    observer.start()
    print(f"Monitoring changes in {local_path}...")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

# Function to check if this is the first run (local folder is empty)
def is_first_run():
    return not os.listdir(local_path)

def main():
    if is_first_run():
        # First run: download everything from the Docker container to the local folder
        download_from_container()
    else:
        # Start monitoring the folder for changes and sync to Docker container
        start_monitoring()

# Corrected main check
if __name__ == "__main__":
    main()
# Out:
# Monitoring changes in D:/Wsoftpro/HR-Payroll/employee_payroll_attendance...
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_employee_extension.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_employee_extension.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_employee_extension.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__init__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__init__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__init__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\account_analytic_line.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/account_analytic_line.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\account_analytic_line.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\custom_invoice.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/custom_invoice.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\custom_invoice.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_attendance_payroll.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_attendance_payroll.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_attendance_payroll.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_public.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_employee_public.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_public.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_leave_extension.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_leave_extension.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_leave_extension.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_payslip.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_payslip.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_payslip.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_payslip_report.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_payslip_report.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_payslip_report.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\payslip_attendance.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/payslip_attendance.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\payslip_attendance.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\update_rate_fallback.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/update_rate_fallback.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\update_rate_fallback.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\work_saturday_schedule.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/work_saturday_schedule.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\work_saturday_schedule.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/__manifest__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\__manifest__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\.DS_Store to odoo16:/mnt/extra-addons/employee_payroll_attendance/.DS_Store...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\.DS_Store to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\__init__.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/__init__.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\__init__.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\auto_generate_payslip.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/auto_generate_payslip.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\auto_generate_payslip.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\custom_duration_timeoff.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/custom_duration_timeoff.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\custom_duration_timeoff.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\full_monthly_fix_price.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/full_monthly_fix_price.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\full_monthly_fix_price.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\generate_salary_wizard.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/generate_salary_wizard.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\generate_salary_wizard.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/models exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to odoo16:/mnt/extra-addons/employee_payroll_attendance/models/hr_employee_extension.py...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\models\hr_employee_extension.py to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/security exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\security\ir.model.access.csv to odoo16:/mnt/extra-addons/employee_payroll_attendance/security/ir.model.access.csv...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\security\ir.model.access.csv to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static/src/css exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\css\custom_style.css to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/src/css/custom_style.css...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\css\custom_style.css to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static/src/css exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\css\tree_view_sticky.css to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/src/css/tree_view_sticky.css...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\css\tree_view_sticky.css to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static/src/js exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\js\custom_timeoff_dashboard.js to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/src/js/custom_timeoff_dashboard.js...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\src\js\custom_timeoff_dashboard.js to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\account_analytic_line_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/account_analytic_line_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\account_analytic_line_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\custom_module_sale.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/custom_module_sale.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\custom_module_sale.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\custom_report_layout.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/custom_report_layout.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\custom_report_layout.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\generate_salary_wizard_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/generate_salary_wizard_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\generate_salary_wizard_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_attendance_payroll_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_attendance_payroll_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_attendance_payroll_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_kpi_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_employee_kpi_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_kpi_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_payslip_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_employee_payslip_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_payslip_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_salary_review_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_employee_salary_review_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_employee_salary_review_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_payslip_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_payslip_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_payslip_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_payslip_views_update.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_payslip_views_update.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_payslip_views_update.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_salary_review_views.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/hr_salary_review_views.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\hr_salary_review_views.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\ir_cron.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/ir_cron.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\ir_cron.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\menu_reporting.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/menu_reporting.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\menu_reporting.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/views exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\work_saturday_schedule_view.xml to odoo16:/mnt/extra-addons/employee_payroll_attendance/views/work_saturday_schedule_view.xml...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\views\work_saturday_schedule_view.xml to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/icon.png...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png.crdownload to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/icon.png.crdownload...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png.crdownload. Error: CreateFile D:\Wsoftpro\HR-Payroll\employee_payroll_attendance\static\icon.png.crdownload: The system cannot find the file specified.
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png.crdownload to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/icon.png.crdownload...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png.crdownload. Error: CreateFile D:\Wsoftpro\HR-Payroll\employee_payroll_attendance\static\icon.png.crdownload: The system cannot find the file specified.
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static exists in the container.
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/icon.png...
# Successfully synced D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\icon.png to Docker container.
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\icon.png to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/icon.png...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\icon.png. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\icon.png to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/icon.png...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\icon.png. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
#
# Directory /mnt/extra-addons/employee_payroll_attendance/static/description is missing in the container, creating it...
# Failed to create directory. Error: mkdir: cannot create directory â€˜/mnt/extra-addons/employee_payroll_attendance/static/descriptionâ€™: Permission denied
#
# Syncing D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html to odoo16:/mnt/extra-addons/employee_payroll_attendance/static/description/index.html...
# Failed to sync D:/Wsoftpro/HR-Payroll/employee_payroll_attendance\static\description\index.html. Error: Error response from daemon: Could not find the file /mnt/extra-addons/employee_payroll_attendance/static/description in container odoo16
